# %% [markdown]
# # **Data loading**
#
# ---

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/tsunami_dataset.csv")

# %%
df.tail()
# Out:
#         ID  YEAR  MONTH   DAY  HOUR  MINUTE  LATITUDE  LONGITUDE  \
# 2254  5753  2020    7.0  22.0   6.0    12.0    55.030   -158.522
# 2255  5750  2020    6.0  18.0  12.0    49.0   -33.294   -177.838
# 2256  5752  2013    4.0  22.0   1.0    16.0    18.081   -102.182
# 2257  5749  1867    6.0  10.0   NaN     NaN    -7.800    110.400
# 2258  5751  2020    6.0  23.0  15.0    29.0    16.029    -95.901
#
#                             LOCATION_NAME      COUNTRY  ...       CAUSE  \
# 2254                 SHUMAGIN ISLANDS, AK          USA  ...  Earthquake
# 2255  S OF RAOUL ISLAND, KERMADEC ISLANDS  NEW ZEALAND  ...  Earthquake
# 2256                               MEXICO       MEXICO  ...  Earthquake
# 2257                                 JAVA    INDONESIA  ...  Earthquake
# 2258               OFF OF COAST OF OAXACA       MEXICO  ...  Earthquake
#
#              EVENT_VALIDITY EQ_MAGNITUDE  EQ_DEPTH  TS_INTENSITY  \
# 2254       Definite Tsunami          7.8      28.0           NaN
# 2255       Definite Tsunami          7.4      10.0           NaN
# 2256       Probable Tsunami          6.0      30.0           NaN
# 2257  Very Doubtful Tsunami          NaN       NaN           NaN
# 2258       Definite Tsunami          7.4      26.0           NaN
#
#             DAMAGE_TOTAL_DESCRIPTION    HOUSES_TOTAL_DESCRIPTION  \
# 2254                             NaN                         NaN
# 2255                             NaN                         NaN
# 2256                             NaN                         NaN
# 2257    Severe (~>$5 to $24 million)  Many (~101 to 1000 houses)
# 2258  Extreme (~$25 million or more)                         NaN
#
#      DEATHS_TOTAL_DESCRIPTION  \
# 2254                      NaN
# 2255                      NaN
# 2256                      NaN
# 2257    Few (~1 to 50 people)
# 2258    Few (~1 to 50 people)
#
#                                                     URL  \
# 2254  https://www.ngdc.noaa.gov/hazel/view/hazards/t...
# 2255  https://www.ngdc.noaa.gov/hazel/view/hazards/t...
# 2256  https://www.ngdc.noaa.gov/hazel/view/hazards/t...
# 2257  https://www.ngdc.noaa.gov/hazel/view/hazards/t...
# 2258  https://www.ngdc.noaa.gov/hazel/view/hazards/t...
#
#                                                COMMENTS
# 2254                                                NaN
# 2255  A small tsunami (12 cm) occurred today followi...
# 2256  In the same subduction zone, earthquakes of Ap...
# 2257  A seaquake was observed in the backarc. While ...
# 2258                                                NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# # **Exploratory data analysis**

# %% [markdown]
# ## **Data visualization**

# %%
print("Dataset Info:")
print(df.info())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2259 entries, 0 to 2258
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        2259 non-null   int64
#  1   YEAR                      2259 non-null   int64
#  2   MONTH                     2155 non-null   float64
#  3   DAY                       2082 non-null   float64
#  4   HOUR                      1308 non-null   float64
#  5   MINUTE                    1235 non-null   float64
#  6   LATITUDE                  2259 non-null   float64
#  7   LONGITUDE                 2259 non-null   float64
#  8   LOCATION_NAME             2250 non-null   object
#  9   COUNTRY                   2259 non-null   object
#  10  REGION                    2258 non-null   object
#  11  CAUSE                     2258 non-null   object
#  12  EVENT_VALIDITY            2259 non-null   object
#  13  EQ_MAGNITUDE              1474 non-null   float64
#  14  EQ_DEPTH                  907 non-null    float64
#  15  TS_INTENSITY              1101 non-null   float64
#  16  DAMAGE_TOTAL_DESCRIPTION  1055 non-null   object
#  17  HOUSES_TOTAL_DESCRIPTION  606 non-null    object
#  18  DEATHS_TOTAL_DESCRIPTION  674 non-null    object
#  19  URL                       2259 non-null   object
#  20  COMMENTS                  2095 non-null   object
# dtypes: float64(9), int64(2), object(10)
# memory usage: 370.7+ KB
# None

# %%
print("Basic Statistics:")
df.describe(include="all")
# Out:
# Basic Statistics:
#                  ID         YEAR        MONTH          DAY         HOUR  \
# count   2259.000000  2259.000000  2155.000000  2082.000000  1308.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean    2332.022134  1819.188136     6.622738    15.700768    11.318807
# std     1665.174408   354.081686     3.460098     8.656968     6.979589
# min        1.000000 -2000.000000     1.000000     1.000000     0.000000
# 25%     1090.500000  1835.500000     4.000000     8.000000     5.000000
# 50%     1932.000000  1909.000000     7.000000    16.000000    11.000000
# 75%     3353.000000  1968.000000    10.000000    23.000000    18.000000
# max     5753.000000  2020.000000    12.000000    31.000000    23.000000
#
#              MINUTE     LATITUDE    LONGITUDE   LOCATION_NAME COUNTRY  ...  \
# count   1235.000000  2259.000000  2259.000000            2250    2259  ...
# unique          NaN          NaN          NaN             861     103  ...
# top             NaN          NaN          NaN  NORTHERN CHILE   JAPAN  ...
# freq            NaN          NaN          NaN              72     308  ...
# mean      28.353846    17.002135    40.346320             NaN     NaN  ...
# std       17.223160    27.730844   104.605369             NaN     NaN  ...
# min        0.000000   -63.000000  -179.971000             NaN     NaN  ...
# 25%       14.000000    -5.000000   -70.200000             NaN     NaN  ...
# 50%       29.000000    23.000000    34.400000             NaN     NaN  ...
# 75%       43.000000    38.670000   137.832500             NaN     NaN  ...
# max       59.000000    71.813000   179.984000             NaN     NaN  ...
#
#              CAUSE    EVENT_VALIDITY EQ_MAGNITUDE    EQ_DEPTH  TS_INTENSITY  \
# count         2258              2259  1474.000000  907.000000   1101.000000
# unique          10                 5          NaN         NaN           NaN
# top     Earthquake  Definite Tsunami          NaN         NaN           NaN
# freq          1743               932          NaN         NaN           NaN
# mean           NaN               NaN     7.046676   36.298787      1.376985
# std            NaN               NaN     0.796125   41.098547      1.840800
# min            NaN               NaN     3.200000    0.000000     -4.140000
# 25%            NaN               NaN     6.600000   17.000000      0.500000
# 50%            NaN               NaN     7.000000   31.000000      1.500000
# 75%            NaN               NaN     7.600000   40.000000      3.000000
# max            NaN               NaN     9.500000  600.000000      9.000000
#
#         DAMAGE_TOTAL_DESCRIPTION    HOUSES_TOTAL_DESCRIPTION  \
# count                       1055                         606
# unique                         4                           4
# top        Limited (<$1 million)  Many (~101 to 1000 houses)
# freq                         365                         263
# mean                         NaN                         NaN
# std                          NaN                         NaN
# min                          NaN                         NaN
# 25%                          NaN                         NaN
# 50%                          NaN                         NaN
# 75%                          NaN                         NaN
# max                          NaN                         NaN
#
#        DEATHS_TOTAL_DESCRIPTION  \
# count                       674
# unique                        4
# top       Few (~1 to 50 people)
# freq                        310
# mean                        NaN
# std                         NaN
# min                         NaN
# 25%                         NaN
# 50%                         NaN
# 75%                         NaN
# max                         NaN
#
#                                                       URL  \
# count                                                2259
# unique                                               2259
# top     https://www.ngdc.noaa.gov/hazel/view/hazards/t...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                  COMMENTS
# count                                                2095
# unique                                               2083
# top     1905-1911. The Matavanu volcano eruption first...
# freq                                                    5
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
# [11 rows x 21 columns]

# %%
print("Missing Values:")
df.isnull().sum()
# Out:
# Missing Values:
# ID                             0
# YEAR                           0
# MONTH                        104
# DAY                          177
# HOUR                         951
# MINUTE                      1024
# LATITUDE                       0
# LONGITUDE                      0
# LOCATION_NAME                  9
# COUNTRY                        0
# REGION                         1
# CAUSE                          1
# EVENT_VALIDITY                 0
# EQ_MAGNITUDE                 785
# EQ_DEPTH                    1352
# TS_INTENSITY                1158
# DAMAGE_TOTAL_DESCRIPTION    1204
# HOUSES_TOTAL_DESCRIPTION    1653
# DEATHS_TOTAL_DESCRIPTION    1585
# URL                            0
# COMMENTS                     164
# dtype: int64

# %%
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
print("Column Data Types:")
df.dtypes
# Out:
# Column Data Types:
# ID                            int64
# YEAR                          int64
# MONTH                       float64
# DAY                         float64
# HOUR                        float64
# MINUTE                      float64
# LATITUDE                    float64
# LONGITUDE                   float64
# LOCATION_NAME                object
# COUNTRY                      object
# REGION                       object
# CAUSE                        object
# EVENT_VALIDITY               object
# EQ_MAGNITUDE                float64
# EQ_DEPTH                    float64
# TS_INTENSITY                float64
# DAMAGE_TOTAL_DESCRIPTION     object
# HOUSES_TOTAL_DESCRIPTION     object
# DEATHS_TOTAL_DESCRIPTION     object
# URL                          object
# COMMENTS                     object
# dtype: object

# %%
for col in df.select_dtypes(include=["object"]).columns:
    print(f"Value counts for {col}:")
    print(df[col].value_counts().head(10))
    print("-----")
# Out:
# Value counts for LOCATION_NAME:
# LOCATION_NAME
# NORTHERN CHILE      72
# CENTRAL CHILE       57
# SANRIKU             42
# S. KURIL ISLANDS    36
# BANDA SEA           33
# S. MEXICO           32
# BISMARCK SEA        28
# S. PERU             28
# SOLOMON ISLANDS     27
# KAMCHATKA           25
# Name: count, dtype: int64
# -----
# Value counts for COUNTRY:
# COUNTRY
# JAPAN               308
# INDONESIA           223
# USA                 164
# CHILE               153
# GREECE              141
# ITALY               110
# RUSSIA               90
# PHILIPPINES          87
# PAPUA NEW GUINEA     74
# NEW ZEALAND          73
# Name: count, dtype: int64
# -----
# Value counts for REGION:
# REGION
# Mediterranean Sea                                    366
# Japan                                                308
# West Coast of South America                          228
# New Caledonia, New Guinea, Solomon Is., Vanuatu      173
# China, North and South Korea, Philippines, Taiwan    164
# E Coast Australia, New Zealand, South Pacific Is.    150
# West Coast of North and Central America              149
# Indian Ocean (including west coast of Australia)     148
# Indonesia (Pacific Ocean) and Malaysia               109
# Caribbean Sea                                        108
# Name: count, dtype: int64
# -----
# Value counts for CAUSE:
# CAUSE
# Earthquake                  1743
# Unknown                      157
# Volcano                      108
# Earthquake and Landslide     105
# Landslide                     83
# Meteorological                26
# Volcano and Earthquake        13
# Questionable Earthquake       12
# Volcano and Landslide         10
# Explosion                      1
# Name: count, dtype: int64
# -----
# Value counts for EVENT_VALIDITY:
# EVENT_VALIDITY
# Definite Tsunami                                                     932
# Questionable Tsunami                                                 464
# Very Doubtful Tsunami                                                413
# Probable Tsunami                                                     355
# Event that only caused a seiche or disturbance in an inland river     95
# Name: count, dtype: int64
# -----
# Value counts for DAMAGE_TOTAL_DESCRIPTION:
# DAMAGE_TOTAL_DESCRIPTION
# Limited (<$1 million)             365
# Moderate (~$1 to $5 million)      276
# Severe (~>$5 to $24 million)      267
# Extreme (~$25 million or more)    147
# Name: count, dtype: int64
# -----
# Value counts for HOUSES_TOTAL_DESCRIPTION:
# HOUSES_TOTAL_DESCRIPTION
# Many (~101 to 1000 houses)          263
# Very Many (~1001 or more houses)    127
# Few (~1 to 50 houses)               124
# Some (~51 to 100 houses)             92
# Name: count, dtype: int64
# -----
# Value counts for DEATHS_TOTAL_DESCRIPTION:
# DEATHS_TOTAL_DESCRIPTION
# Few (~1 to 50 people)               310
# Many (~101 to 1000 people)          172
# Very Many (~1001 or more people)    131
# Some (~51 to 100 people)             61
# Name: count, dtype: int64
# -----
# Value counts for URL:
# URL
# https://www.ngdc.noaa.gov/hazel/view/hazards/tsunami/event-more-info/5751    1
# https://www.ngdc.noaa.gov/hazel/view/hazards/tsunami/event-more-info/12      1
# https://www.ngdc.noaa.gov/hazel/view/hazards/tsunami/event-more-info/481     1
# https://www.ngdc.noaa.gov/hazel/view/hazards/tsunami/event-more-info/5737    1
# https://www.ngdc.noaa.gov/hazel/view/hazards/tsunami/event-more-info/5736    1
# https://www.ngdc.noaa.gov/hazel/view/hazards/tsunami/event-more-info/5734    1
# https://www.ngdc.noaa.gov/hazel/view/hazards/tsunami/event-more-info/5733    1
# https://www.ngdc.noaa.gov/hazel/view/hazards/tsunami/event-more-info/5726    1
# https://www.ngdc.noaa.gov/hazel/view/hazards/tsunami/event-more-info/5727    1
# https://www.ngdc.noaa.gov/hazel/view/hazards/tsunami/event-more-info/5720    1
# Name: count, dtype: int64
# -----
# Value counts for COMMENTS:
# COMMENTS
# 1905-1911. The Matavanu volcano eruption first began on August 4 of 1905. The flows occasionally generated small tsunamis by avalanching materia1 into the sea. Several tsunami-like waves were observed when the crater was more than usually active. It is interesting to note that several so-called 'tidal' waves have occurred during the eruption. The following were noticed at Matautu by Amtmann Williams\r\n\r\n          November 28th, 1906 5:30 p.m. \r\n          June 8th, 1907 at noon \r\n          June 19th, 1907 3 a.m. \r\n          June 27th, 1907 between 6 & 7 p.m. \r\n          July 9th, 1907 6:45 p.m. \r\n          July 25th, 1907 11 a.m. \r\n\r\nThe tide usually rises and falls about 4 feet at Matautu. Most of these waves did not exceed 6 to 8 feet in height, and as many of them occurred at low or half-tide, and there was no heavy sea on at the time, little damage was done, although in several cases the main road of the town was flooded.\r\n\r\n(above from reference #337)\r\n\r\n<P>For more information link to the the \r\n<B><U><a href="http://www.ngdc.noaa.gov/idb/struts/results?EQ_0=1326&t=101650&s=9&d=99,91,95,93&nd=display"','tsueqWindow','resizable=yes,menubar=no,scrollbars=yes,width=800,height=600,left=5,top=50', target="blank"); ">tsunami event</a></B></U> and \r\n<B><U><a href="http://www.ngdc.noaa.gov/idb/struts/results?EQ_0=2068&t=102557&s=1&d=140,145,175,180&nd=display"','tsueqWindow','resizable=yes,menubar=no,scrollbars=yes,width=800,height=600,left=5,top=50', target="blank"); ">volcanic eruption</a></B></U> on August 4, 1905.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        5
# More than 200 moderate to large earthquakes occurred on the New Madrid fault between Dec 16, 1811 and Mar 15, 1812. The New Madrid earthquakes generated several waves in the rivers, raised water levels, agitated waters, and affected navigation.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    3
# <P><blockquote><i>Reference #414:</i></blockquote> \r\nSeptember 16, 1952 - March 25, 1953. There was a multiple eruption of the Miyejin submarine volcano (31 deg 56.7 min N., 140 deg 0.5 min E.) 130 km south of Hachijo Island. The augite-hypersthene-dacite composition of the lavas determined the explosive nature of the eruptions. All the explosions were well recorded by the hydrophones of the American SOFAR system, including those on the coast of California. Some of the eruptions were observed visually from ships and airplanes by Japanese specialists. Thus, during the weak eruption of September 23 at 13h 40m, a water dome, with protuberances 600-800 m high and 2 km in diameter, arose over the volcano. No seaquake was felt , but waves 50 m long and 2 m high spread over the sea surface. During the stronger eruptions weak tsunamis were generated, 52 of which were registered by the tide gauge on Hachijo Island. The strongest of these waves were also registered by tide gauges on Jogashima Island and Cape\r\nOmae on the south coast of Japan. The travel time of the waves to Hachijo Island was about 30 minutes, the period 1.5 minutes, the height 10-90 cm. In the nature of dispersion and other parameters, the waves corresponded to theoretical Cauchy-Poisson waves from an initial impulse with a source diameter of 2 <U>+</u> km. Some waves were like pulses. This was apparently due to the interference of waves bending around both sides of Aoga-shima Island, midway between the volcano and Hachijo Island. \r\n<P>The tsunami of September 26 was recorded in Hilo, in the Hawailan Islands with an amplitude of less than 0.1 m. \r\n<P>The ship "Kiyo Maru No 5" of the Japanese hydrographic service, which had come out to study the eruption, was lost in the eruption of September 24.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         3
# A major earthquake with a moment magnitude of 7.1 (USGS magnitude) occurred at 16:55:02 UTC 20 August 2011 (day 232) and was located 39 miles/63 km SSW of Port-Vila, Efate, Vanuatu (18.260S, 168.069E, 25.2 mi/40.6 km depth--USGS location).\r\n<P>A second major earthquake with a moment magnitude of 7.0 (USGS magnitude) occurred at 18:19:02 UTC 20 August 2011 (day 232) and was located 42 miles/69 km SSW of Port-Vila, Efate, Vanuatu (18.287S, 168.132E, 17.7 mi/28.5 km depth--USGS location).\r\n<P>(all above from reference 9763)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      2
# Reference #96 lists possible tsunami.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   2
# The M.M. Company's steamer Pacifique, from the New Hebrides and Noumea, brings the news that on November 22 and 24 severe shocks of earthquake were experienced at Port Vila and were followed by a tidal wave. (reference #7375)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       2
# three earthquakes that occurred during the 19 November 2017 seismic crisis that occurred east of Mare Island: two very small tsunamis were triggered by the Mw = 6.3 and 6.6 foreshocks of the Mw = 7.0 earthquake, which triggered a tsunami reaching a maximum amplitude of 0.8m at Ouinne tide gauge. Despite their small amplitude, they are very well recorded and shown in Fig. 8. (reference #12506)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             2
# Recorded mareograms in stations Gelendzik, Tuapse, Opasnoe, Feodosia, Yalta, Batumi, Mariupol and Kerch. Tsunami amplitude in Gelendzik 20-25 cm. Tsunami intensity I. (reference #4139)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# <P>This earthquake was characterized by extensive fault scarps, subsidence and uplift, a massive landslide, and a seiche in Hebgen Lake. (reference #542)\r\n<P>The earthquake also caused a northward tilt of the Hebgen Lake bed. This triggered a reported 20-foot wall of water that overtopped Hebgen Dam followed by several 3-4 foot surges. (reference #12600)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# <P><blockquote><i>Reference #414:</i></blockquote> \r\n<P>1953, April 23, 16:24:22 UTC, validity 1, 4.5 S, 153.3 E, magnitude 7.4. Tsunami event questionable, intensity 0. There was an earthquake in New Britain. Structures were damaged and fractures formed in the ground. There was a tsunami, which according to press reports, spread to the Hawaiian Islands. [23.IV; 16h24m22s; 4.5 S., 153.3 E.; M=7.4.] \r\n<P><blockquote><i>Reference #99:</i></blockquote> \r\n<P>1953, April 24. The upheaval caused water to be sucked from Simpson harbour in which Rabaul nestles. It ebbed and flowed several times before the level became normal. <P><blockquote><i>Reference #79:</i></blockquote> \r\n<P>1953, April 23, 16:24 UTC, 4 S, 154 E, magnitude 7.5 MS. Source area New Ireland, tsunami observation Indonesia?. Statement of damage in list of tsunamis published by Japan Meteorological Agency (Anon., 1961) is probably a mistake. There is no confirmation of anything except quake effects. <P><blockquote><i>Reference #9333:</i></blockquote> \r\n<P>Big Quake in new Britain, Friday, April 24, 1953, Barrier Miner, New South Wales. Sydney: A severe earthquake centred in the middle of the island of New Britain, 2060 miles north of Sydney, was recorded today at the Riverview Observatory. Hawaii and other Pacific islands have been alerted to expect a tidal wave. \r\n<P><blockquote><i>Reference #9332:</i></blockquote> \r\n<P>Quake Shakes Rabaul, April 25, 1953, The Mercury, Hobart, Tasmania. Canberra, Friday.--An earthquake described by U.S. seismologists as a "rip - snorter" occurred near Rabaul today, but no casualties resulted. Houses, tanks and power lines were damaged. There was no panic... Landslides brought trees to earth, smashing light and power lines and blocking roads. The epicentre of the upheaval was estimated within 30 miles and New Britain is still feeling reaction to a settling down somewhere under the sea. Water was sucked from Simpson Harbour, in which Rabaul nestles. It went and came back several times before the level became normal. An hour after the first shock at 2:30 a.m., water rose to an unusual height at Kokopo, beyond Blanche Bay, but quickly subsided.... It caused a tidal wave alert in Hawaii, but the warning was later cancelled. Another tremor shook Rabaul Town at 10 a.m.    1
# Name: count, dtype: int64
# -----

# %%
print("Correlation Matrix:")
df.corr(numeric_only=True)
# Out:
# Correlation Matrix:
#                     ID      YEAR     MONTH       DAY      HOUR    MINUTE  \
# ID            1.000000  0.200631 -0.042912 -0.033704  0.063095  0.035084
# YEAR          0.200631  1.000000 -0.027363 -0.035315  0.005246  0.047520
# MONTH        -0.042912 -0.027363  1.000000  0.024017  0.019341  0.003390
# DAY          -0.033704 -0.035315  0.024017  1.000000 -0.000267 -0.007432
# HOUR          0.063095  0.005246  0.019341 -0.000267  1.000000 -0.000727
# MINUTE        0.035084  0.047520  0.003390 -0.007432 -0.000727  1.000000
# LATITUDE     -0.050727 -0.188330 -0.021566  0.010690 -0.033324 -0.017571
# LONGITUDE    -0.024029 -0.004802 -0.004500 -0.005008 -0.020373 -0.015712
# EQ_MAGNITUDE -0.104516  0.022374  0.074943  0.026994  0.013464  0.034561
# EQ_DEPTH     -0.131465 -0.137092  0.010691  0.019089 -0.039885  0.000482
# TS_INTENSITY  0.040662 -0.367241 -0.019645  0.016824  0.038308 -0.010976
#
#               LATITUDE  LONGITUDE  EQ_MAGNITUDE  EQ_DEPTH  TS_INTENSITY
# ID           -0.050727  -0.024029     -0.104516 -0.131465      0.040662
# YEAR         -0.188330  -0.004802      0.022374 -0.137092     -0.367241
# MONTH        -0.021566  -0.004500      0.074943  0.010691     -0.019645
# DAY           0.010690  -0.005008      0.026994  0.019089      0.016824
# HOUR         -0.033324  -0.020373      0.013464 -0.039885      0.038308
# MINUTE       -0.017571  -0.015712      0.034561  0.000482     -0.010976
# LATITUDE      1.000000  -0.025100     -0.202534 -0.115831      0.192015
# LONGITUDE    -0.025100   1.000000     -0.056175 -0.017515     -0.205536
# EQ_MAGNITUDE -0.202534  -0.056175      1.000000  0.106240      0.119568
# EQ_DEPTH     -0.115831  -0.017515      0.106240  1.000000      0.048720
# TS_INTENSITY  0.192015  -0.205536      0.119568  0.048720      1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

num_cols = df.select_dtypes(include=np.number).columns
plt.figure(figsize=(15, 8))
for i, col in enumerate(num_cols, 1):
    plt.subplot(len(num_cols)//3 + 1, 3, i)
    sns.boxplot(x=df[col])
    plt.title(col)
plt.tight_layout()
plt.show()
print("Boxplots plotted for numerical columns.")
# Out:
# Boxplots plotted for numerical columns.

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.show()
print("Correlation heatmap displayed.")
# Out:
# Correlation heatmap displayed.

# %% [markdown]
# ## **Missing value imputation**

# %%
print("Missing Values Before Imputation:")
df.isnull().sum()
# Out:
# Missing Values Before Imputation:
# ID                             0
# YEAR                           0
# MONTH                        104
# DAY                          177
# HOUR                         951
# MINUTE                      1024
# LATITUDE                       0
# LONGITUDE                      0
# LOCATION_NAME                  9
# COUNTRY                        0
# REGION                         1
# CAUSE                          1
# EVENT_VALIDITY                 0
# EQ_MAGNITUDE                 785
# EQ_DEPTH                    1352
# TS_INTENSITY                1158
# DAMAGE_TOTAL_DESCRIPTION    1204
# HOUSES_TOTAL_DESCRIPTION    1653
# DEATHS_TOTAL_DESCRIPTION    1585
# URL                            0
# COMMENTS                     164
# dtype: int64

# %%
num_cols = df.select_dtypes(include=np.number).columns
for col in num_cols:
    df[col].fillna(df[col].median(), inplace=True)
print("Numeric missing values imputed with median.")
df[num_cols].isnull().sum()
# Out:
# Numeric missing values imputed with median.
# /tmp/ipython-input-1562147211.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# ID              0
# YEAR            0
# MONTH           0
# DAY             0
# HOUR            0
# MINUTE          0
# LATITUDE        0
# LONGITUDE       0
# EQ_MAGNITUDE    0
# EQ_DEPTH        0
# TS_INTENSITY    0
# dtype: int64

# %%
cat_cols = df.select_dtypes(include="object").columns
for col in cat_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)
print("Categorical missing values imputed with mode.")
df[cat_cols].isnull().sum()
# Out:
# Categorical missing values imputed with mode.
# /tmp/ipython-input-2622268567.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)
# LOCATION_NAME               0
# COUNTRY                     0
# REGION                      0
# CAUSE                       0
# EVENT_VALIDITY              0
# DAMAGE_TOTAL_DESCRIPTION    0
# HOUSES_TOTAL_DESCRIPTION    0
# DEATHS_TOTAL_DESCRIPTION    0
# URL                         0
# COMMENTS                    0
# dtype: int64

# %%
print("Missing Values After Imputation:")
df.isnull().sum()
# Out:
# Missing Values After Imputation:
# ID                          0
# YEAR                        0
# MONTH                       0
# DAY                         0
# HOUR                        0
# MINUTE                      0
# LATITUDE                    0
# LONGITUDE                   0
# LOCATION_NAME               0
# COUNTRY                     0
# REGION                      0
# CAUSE                       0
# EVENT_VALIDITY              0
# EQ_MAGNITUDE                0
# EQ_DEPTH                    0
# TS_INTENSITY                0
# DAMAGE_TOTAL_DESCRIPTION    0
# HOUSES_TOTAL_DESCRIPTION    0
# DEATHS_TOTAL_DESCRIPTION    0
# URL                         0
# COMMENTS                    0
# dtype: int64
